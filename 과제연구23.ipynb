# %%
def traffic1 (a,b,c,d,e,f,g,h):
    
    goal=2
    cnt=e+2
    while True:
        if (cnt%4)+1==a and goal==2:
            goal=1
            cnt+=1
        elif (cnt%4)+1==b and goal==1:
            goal=4
            cnt+=1
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt-1

def traffic2 (a,b,c,d,e,f,g,h):
    goal=6
    cnt=g
    while True:
        if (cnt%4)+1==h and goal==6:
            goal=5
            cnt+=3
        elif (cnt%4)+1==d and goal==5:
            goal=4
            cnt+=1
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt-1

def traffic3 (a,b,c,d,e,f,g,h):
    goal=2
    cnt=e
    while True:
        if (cnt%4)+1==f and goal==2:
            goal=5
            cnt+=3
        elif (cnt%4)+1==d and goal==5:
            goal=4
            cnt+=1
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt-1

def traffic4 (a,b,c,d,e,f,g,h):
    goal=2
    cnt=e+2
    while True:
        
        if (cnt%4)+1==c and goal==2:
            goal=5
            cnt+=1
        elif (cnt%4)+1==d and goal==5:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt-1
def traffic5 (a,b,c,d,e,f,g,h):
    goal=6
    cnt=g
    while True:
        
        if (cnt%4)+1==h and goal==6:
            goal=5
            cnt+=1
        elif (cnt%4)+1==f and goal==5:
            goal=2
            cnt+=3
        elif (cnt%4)+1==a and goal==2:
            goal=1
            cnt+=1
        elif (cnt%4)+1==b and goal==1:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt-1

def traffic6 (a,b,c,d,e,f,g,h):
    goal=6
    cnt=g
    while True:
        
        if (cnt%4)+1==h and goal==6:
            goal=5
            cnt+=3
        elif (cnt%4)+1==c and goal==5:
            goal=2
            cnt+=1
        elif (cnt%4)+1==a and goal==2:
            goal=1
            cnt+=1
        elif (cnt%4)+1==b and goal==1:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt-1

def traffic7 (a,b,c,d,e,f,g,h):
    goal=2
    cnt=e
    while True:
        
        if (cnt%4)+1==f and goal==2:
            goal=5
            cnt+=3
        elif (cnt%4)+1==c and goal==5:
            goal=20
            cnt+=1
        elif (cnt%4)+1==a and goal==20:
            goal=1
            cnt+=1
        elif (cnt%4)+1==b and goal==1:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt-1

def traffic8 (a,b,c,d,e,f,g,h):
    goal=6
    cnt=g
    while True:
        
        if (cnt%4)+1==h and goal==6:
            goal=5
            cnt+=1
        elif (cnt%4)+1==f and goal==5:
            goal=2
            cnt+=3
        elif (cnt%4)+1==c and goal==2:
            goal=1
            cnt+=1
        elif (cnt%4)+1==d and goal==1:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt-1

# %%
def fast_traffic(a,b,c,d,e,f,g,h):
    traf=[traffic1(a,b,c,d,e,f,g,h),traffic2(a,b,c,d,e,f,g,h),traffic3(a,b,c,d,e,f,g,h),traffic4(a,b,c,d,e,f,g,h),traffic5(a,b,c,d,e,f,g,h),traffic6(a,b,c,d,e,f,g,h),traffic7(a,b,c,d,e,f,g,h),traffic8(a,b,c,d,e,f,g,h)]
    return min(traf)

# %%
def path_traffic(a,b,c,d,e,f,g,h):
    num=['e-a-b','g-h-d','e-f-d','e-c-d','g-h-f-a-b','g-h-c-a-b','e-f-c-a-b','g-h-f-c-d']
    traf=[traffic1(a,b,c,d,e,f,g,h),traffic2(a,b,c,d,e,f,g,h),traffic3(a,b,c,d,e,f,g,h),traffic4(a,b,c,d,e,f,g,h),traffic5(a,b,c,d,e,f,g,h),traffic6(a,b,c,d,e,f,g,h),traffic7(a,b,c,d,e,f,g,h),traffic8(a,b,c,d,e,f,g,h)]
    temp = fast_traffic(a,b,c,d,e,f,g,h)
    for i in range(8):
        if temp==traf[i]:
            yield num[i]

# %%
def traffic_time(a,b,c,d,e,f,g,h):
    print(traffic1(a,b,c,d,e,f,g,h))
    print(traffic2(a,b,c,d,e,f,g,h))
    print(traffic3(a,b,c,d,e,f,g,h))
    print(traffic4(a,b,c,d,e,f,g,h))
    print(traffic5(a,b,c,d,e,f,g,h))
    print(traffic6(a,b,c,d,e,f,g,h))
    print(traffic7(a,b,c,d,e,f,g,h))
    print(traffic8(a,b,c,d,e,f,g,h))

# %%
def tritraffic1 (a,b,c,d,e,f,g,h):
    
    goal=2
    cnt=e+2
    while True:
        if ((cnt-1)%3)==a%3 and goal==2:
            goal=1
            cnt+=1
        elif ((cnt-1)%3)==b%3 and goal==1:
            goal=4
            cnt+=1
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def tritraffic2 (a,b,c,d,e,f,g,h):
    goal=6
    cnt=g
    while True:
        if ((cnt-1)%3)==h%3 and goal==6:
            goal=5
            cnt+=3
        elif ((cnt-1)%3)==d%3 and goal==5:
            goal=4
            cnt+=1
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def tritraffic3 (a,b,c,d,e,f,g,h):
    goal=2
    cnt=e
    while True:
        if ((cnt-1)%3)==f%3 and goal==2:
            goal=5
            cnt+=3
        elif ((cnt-1)%3)==d%3 and goal==5:
            goal=4
            cnt+=1
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def tritraffic4 (a,b,c,d,e,f,g,h):
    goal=2
    cnt=e+2
    while True:
        
        if ((cnt-1)%3)==c%3 and goal==2:
            goal=5
            cnt+=1
        elif ((cnt-1)%3)==d%3 and goal==5:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt
def tritraffic5 (a,b,c,d,e,f,g,h):
    goal=6
    cnt=g
    while True:
        
        if (cnt%3)==h%3 and goal==6:
            goal=5
            cnt+=1
        elif (cnt%3)==f%3 and goal==5:
            goal=2
            cnt+=3
        elif (cnt%3)==a%3 and goal==2:
            goal=1
            cnt+=1
        elif (cnt%3)==b%3 and goal==1:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def tritraffic6 (a,b,c,d,e,f,g,h):
    goal=6
    cnt=g
    while True:
        
        if (cnt%3)==h%3 and goal==6:
            goal=5
            cnt+=3
        elif (cnt%3)==c%3 and goal==5:
            goal=2
            cnt+=1
        elif (cnt%3)==a%3 and goal==2:
            goal=1
            cnt+=1
        elif (cnt%3)==b%3 and goal==1:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def tritraffic7 (a,b,c,d,e,f,g,h):
    goal=2
    cnt=e
    while True:
        
        if (cnt%3)==f%3 and goal==2:
            goal=5
            cnt+=3
        elif (cnt%3)==c%3 and goal==5:
            goal=20
            cnt+=1
        elif (cnt%3)==a%3 and goal==20:
            goal=1
            cnt+=1
        elif (cnt%3)==b%3 and goal==1:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def tritraffic8 (a,b,c,d,e,f,g,h):
    goal=6
    cnt=g
    while True:
        
        if (cnt%3)==h%3 and goal==6:
            goal=5
            cnt+=1
        elif (cnt%3)==f%3 and goal==5:
            goal=2
            cnt+=3
        elif (cnt%3)==c%3 and goal==2:
            goal=1
            cnt+=1
        elif (cnt%3)==d%3 and goal==1:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def trifast_traffic(a,b,c,d,e,f,g,h):
    traf=[tritraffic1(a,b,c,d,e,f,g,h),tritraffic2(a,b,c,d,e,f,g,h),tritraffic3(a,b,c,d,e,f,g,h),tritraffic4(a,b,c,d,e,f,g,h),tritraffic5(a,b,c,d,e,f,g,h),tritraffic6(a,b,c,d,e,f,g,h),tritraffic7(a,b,c,d,e,f,g,h),tritraffic8(a,b,c,d,e,f,g,h)]
    return min(traf)

def tripath_traffic(a,b,c,d,e,f,g,h):
    num=['e-a-b','g-h-d','e-f-d','e-c-d','g-h-f-a-b','g-h-c-a-b','e-f-c-a-b','g-h-f-c-d']
    traf=[tritraffic1(a,b,c,d,e,f,g,h),tritraffic2(a,b,c,d,e,f,g,h),tritraffic3(a,b,c,d,e,f,g,h),tritraffic4(a,b,c,d,e,f,g,h),tritraffic5(a,b,c,d,e,f,g,h),tritraffic6(a,b,c,d,e,f,g,h),tritraffic7(a,b,c,d,e,f,g,h),tritraffic8(a,b,c,d,e,f,g,h)]
    temp = trifast_traffic(a,b,c,d,e,f,g,h)
    for i in range(8):
        if temp==traf[i]:
            yield num[i]

# %%
trifast_traffic(2,3,3,1,2,1,3,2)
# Out:
# 6

# %%
for i in tripath_traffic(2,3,3,1,2,1,3,2):
    print(i)
# Out:
# e-a-b

# %%
print(trifast_traffic(1,2,3,1,2,1,3,2))
for i in tripath_traffic(1,2,3,1,2,1,3,2):
    print(i)
# Out:
# 5
# e-a-b

# %%
print(trifast_traffic(2,3,1,2,2,1,3,2))
for i in tripath_traffic(2,3,1,2,2,1,3,2):
    print(i)
# Out:
# 5
# e-c-d

# %%
print(trifast_traffic(3,1,1,2,2,1,3,2))
for i in tripath_traffic(3,1,1,2,2,1,3,2):
    print(i)
# Out:
# 5
# e-c-d

# %%
print(trifast_traffic(1,2,2,3,3,2,2,1))
for i in tripath_traffic(1,2,2,3,3,2,2,1):
    print(i)
print(trifast_traffic(2,3,1,2,3,2,2,1))
for i in tripath_traffic(2,3,1,2,3,2,2,1):
    print(i)
print(trifast_traffic(1,2,3,1,3,2,2,1))
for i in tripath_traffic(1,2,3,1,3,2,2,1):
    print(i)
print(trifast_traffic(3,1,1,2,3,2,2,1))
for i in tripath_traffic(3,1,1,2,3,2,2,1):
    print(i)
# Out:
# 6
# e-c-d
# 6
# e-a-b
# 7
# g-h-d
# e-c-d
# 7
# e-a-b

# %%
print(trifast_traffic(1,3,2,1,3,2,2,1))
for i in tripath_traffic(1,3,2,1,3,2,2,1):
    print(i)
print(trifast_traffic(1,3,3,2,3,2,2,1))
for i in tripath_traffic(1,3,3,2,3,2,2,1):
    print(i)
print(trifast_traffic(2,1,1,3,3,2,2,1))
for i in tripath_traffic(2,1,1,3,3,2,2,1):
    print(i)
print(trifast_traffic(2,3,3,1,3,2,2,1))
for i in tripath_traffic(2,3,3,1,3,2,2,1):
    print(i)
print(trifast_traffic(3,1,2,3,3,2,2,1))
for i in tripath_traffic(3,1,2,3,3,2,2,1):
    print(i)
print(trifast_traffic(3,2,1,3,3,2,2,1))
for i in tripath_traffic(3,2,1,3,3,2,2,1):
    print(i)
    
    
print(trifast_traffic(1,3,2,1,2,1,3,2))
for i in tripath_traffic(1,2,2,3,2,1,3,2):
    print(i)
print(trifast_traffic(1,3,3,2,2,1,3,2))
for i in tripath_traffic(2,3,1,2,2,1,3,2):
    print(i)
print(trifast_traffic(2,1,1,3,2,1,3,2))
for i in tripath_traffic(1,2,3,1,2,1,3,2):
    print(i)
print(trifast_traffic(2,3,3,1,2,1,3,2))
for i in tripath_traffic(3,1,1,2,2,1,3,2):
    print(i)
print(trifast_traffic(3,1,2,3,2,1,3,2))
for i in tripath_traffic(1,2,3,1,2,1,3,2):
    print(i)
print(trifast_traffic(3,2,1,3,2,1,3,2))
for i in tripath_traffic(3,1,1,2,2,1,3,2):
    print(i)
# Out:
# 7
# g-h-d
# e-c-d
# 8
# g-h-d
# e-f-d
# e-c-d
# 7
# e-a-b
# 6
# e-a-b
# 6
# e-c-d
# 8
# e-a-b
# 6
# e-a-b
# 6
# e-c-d
# 6
# e-a-b
# 6
# e-c-d
# 6
# e-a-b
# 6
# e-c-d

# %%
def tl(p,q):
    if len(p)==4:
        if len(q)==4:
            return trifast_traffic(p[0],p[1],p[2],p[3],q[0],q[1],q[2],q[3])

# %%
def tpl(p,q):
    if len(p)==4:
        if len(q)==4:
            return tripath_traffic(p[0],p[1],p[2],p[3],q[0],q[1],q[2],q[3])

# %%
a2=[[1,2,2,3],[1,2,3,1],[2,3,1,2],[3,1,1,2]]
a3=[[1,3,2,1],[1,3,3,2],[2,1,1,3],[2,3,3,1],[3,1,2,3],[3,2,1,3]]
a4=[[2,1,3,2],[3,2,2,1]]

for i in range(len(a2)):
    for j in range(len(a2)):
        print(tl(a2[i],a2[j]))
        for k in tpl(a2[i],a2[j]):
            print(k)
# Out:
# 6
# e-a-b
# 6
# e-a-b
# 6
# e-a-b
# 7
# g-h-d
# e-c-d
# 5
# e-c-d
# 5
# e-c-d
# 6
# e-a-b
# 8
# g-h-d
# e-f-d
# e-c-d
# 6
# e-f-d
# e-c-d
# 6
# e-f-d
# e-c-d
# 6
# g-h-d
# e-c-d
# 6
# g-h-d
# 5
# e-a-b
# 5
# e-a-b
# 6
# g-h-d
# e-c-d
# 6
# g-h-d

# %%
for i in tripath_traffic(1,3,3,2,2,3,3,1):
    print(i)
# Out:
# e-a-b

# %%
tritraffic1(1,3,3,2,2,3,3,1)
# Out:
# 6

# %%
a2=[[1,2,2,3],[1,2,3,1],[2,3,1,2],[3,1,1,2]]
a3=[[1,3,2,1],[1,3,3,2],[2,1,1,3],[2,3,3,1],[3,1,2,3],[3,2,1,3]]
a4=[[2,1,3,2],[3,2,2,1]]

# %%
def count_path(p,q):
    if len(p)==4:
        if len(q)==4:
            for i in tpl(p,q):
                if
# Out:
#   File "<ipython-input-407-e34390458fbf>", line 5
#     if
#        ^
# SyntaxError: invalid syntax

# %%
a2=[[1,2,2,3],[1,2,3,1],[2,3,1,2],[3,1,1,2]]
a3=[[1,3,2,1],[1,3,3,2],[2,1,1,3],[2,3,3,1],[3,1,2,3],[3,2,1,3]]
a4=[[2,1,3,2],[3,2,2,1]]

cnt=0
cntg=0
cnt2=0
cntg2=0
cnt3=0
cntg3=0

for i in range(len(a3)):
    for j in range(len(a2)):
        for k in tpl(a3[i],a2[j]):
            if k[0]=='e':
                cnt+=1
                continue
            else:
                cntg+=1
                continue
print(cnt,cntg)
print('----------------------------------')
for i in range(len(a4)):
    for j in range(len(a2)):
        for k in tpl(a4[i],a2[j]):
            if k[0]=='e':
                cnt2+=1
                continue
            else:
                cntg2+=1
                continue
print(cnt2,cntg2)
print('----------------------------------')
for i in range(len(a4)):
    for j in range(len(a3)):
        for k in tpl(a4[i],a3[j]):
            if k[0]=='e':
                cnt3+=1
                continue
            else:
                cntg3+=1
                continue
print(cnt3,cntg3)

# %%
a2=[[1,2,2,3],[1,2,3,1],[2,3,1,2],[3,1,1,2]]
a3=[[1,3,2,1],[1,3,3,2],[2,1,1,3],[2,3,3,1],[3,1,2,3],[3,2,1,3]]
a4=[[2,1,3,2],[3,2,2,1]]

for i in range(len(a2)):
    for j in range(len(a3)):
        print(tl(a2[i],a3[j]))
        for k in tpl(a2[i],a3[j]):
            print(k)
print('----------------------------------')
for i in range(len(a2)):
    for j in range(len(a4)):
        print(tl(a2[i],a4[j]))
        for k in tpl(a2[i],a4[j]):
            print(k)
print('----------------------------------')
for i in range(len(a3)):
    for j in range(len(a4)):
        print(tl(a3[i],a4[j]))
        for k in tpl(a3[i],a4[j]):
            print(k)
# Out:
# 5
# e-a-b
# 5
# e-a-b
# 5
# e-a-b
# 5
# e-a-b
# 6
# g-h-d
# e-c-d
# 6
# g-h-d
# e-c-d
# 4
# e-c-d
# 4
# e-c-d
# 5
# e-a-b
# 5
# e-a-b
# 7
# g-h-d
# e-f-d
# e-c-d
# 7
# g-h-d
# e-c-d
# 5
# e-c-d
# 5
# e-c-d
# 5
# e-c-d
# 5
# e-c-d
# 6
# e-a-b
# 6
# e-a-b
# 4
# e-a-b
# 4
# e-a-b
# 5
# e-c-d
# 5
# e-c-d
# 7
# e-a-b
# 7
# e-a-b
# ----------------------------------
# 5
# e-a-b
# 6
# e-c-d
# 5
# e-a-b
# 7
# g-h-d
# e-c-d
# 5
# e-c-d
# 6
# e-a-b
# 5
# e-c-d
# 7
# e-a-b
# ----------------------------------
# 6
# e-a-b
# 7
# g-h-d
# e-c-d
# 6
# e-a-b
# 8
# g-h-d
# e-f-d
# e-c-d
# 6
# e-c-d
# 7
# e-a-b
# 6
# e-a-b
# 6
# e-a-b
# 6
# e-c-d
# 6
# e-c-d
# 6
# e-c-d
# 8
# e-a-b

# %%
a2=[[1,2,2,3],[1,2,3,1],[2,3,1,2],[3,1,1,2]]
a3=[[1,3,2,1],[1,3,3,2],[2,1,1,3],[2,3,3,1],[3,1,2,3],[3,2,1,3]]
a4=[[2,1,3,2],[3,2,2,1]]

for i in range(len(a2)):
    for j in range(len(a2)):
        print(tl(a2[i],a2[j]))
        for k in tpl(a2[i],a2[j]):
            print(k)
print('----------------------------------')
for i in range(len(a3)):
    for j in range(len(a3)):
        print(tl(a3[i],a3[j]))
        for k in tpl(a3[i],a3[j]):
            print(k)
print('----------------------------------')
for i in range(len(a4)):
    for j in range(len(a4)):
        print(tl(a4[i],a4[j]))
        for k in tpl(a4[i],a4[j]):
            print(k)
# Out:
# 7
# e-a-b
# 7
# e-a-b
# 7
# e-a-b
# 8
# g-h-d
# e-c-d
# 6
# e-c-d
# 6
# e-c-d
# 7
# e-a-b
# 9
# g-h-d
# e-f-d
# e-c-d
# 7
# e-f-d
# e-c-d
# 7
# e-f-d
# e-c-d
# 7
# g-h-d
# e-c-d
# 7
# g-h-d
# 6
# e-a-b
# 6
# e-a-b
# 7
# g-h-d
# e-c-d
# 7
# g-h-d
# ----------------------------------
# 8
# e-a-b
# 8
# e-a-b
# 8
# e-a-b
# 8
# e-a-b
# 9
# g-h-d
# e-f-d
# e-c-d
# 9
# g-h-d
# e-c-d
# 7
# e-c-d
# 7
# e-c-d
# 8
# e-a-b
# 8
# e-a-b
# 10
# g-h-d
# e-f-d
# e-c-d
# 10
# g-h-d
# e-f-d
# e-c-d
# 8
# e-f-d
# e-c-d
# 8
# e-f-d
# e-c-d
# 8
# g-h-d
# e-c-d
# 8
# e-f-d
# e-c-d
# 8
# g-h-d
# 8
# g-h-d
# 6
# e-c-d
# 6
# e-c-d
# 8
# e-a-b
# 8
# e-a-b
# 8
# e-a-b
# 8
# e-a-b
# 6
# e-a-b
# 6
# e-a-b
# 8
# g-h-d
# e-c-d
# 8
# e-f-d
# e-c-d
# 8
# g-h-d
# e-c-d
# 8
# g-h-d
# e-c-d
# 7
# e-a-b
# 7
# e-a-b
# 8
# g-h-d
# e-c-d
# 8
# e-f-d
# e-c-d
# 8
# g-h-d
# 8
# g-h-d
# ----------------------------------
# 9
# e-a-b
# 9
# e-a-b
# 9
# e-f-d
# e-c-d
# 9
# g-h-d
# e-c-d

# %%
def traffic_picture(n):
    for i in range(1,5):
        for j in range(1,5):
            for k in range(1,5):
                for l in range(1,5):
                    for m in range(1,5):
                        for q in range(1,5):
                            for o in range(1,5):
                                for p in range(1,5):
                                    if i==1 or j==1 or k==1 or l==1:
                                        if m==1 or q==1 or o==1 or p==1:
                                            if i==2 or j==2 or k==2 or l==2:
                                                if m==2 or q==2 or o==2 or p==2:
                                                    if i==3 or j==3 or k==3 or l==3:
                                                        if m==3 or q==3 or o==3 or p==3:
                                                            if i==4 or j==4 or k==4 or l==4:
                                                                if m==4 or q==4 or o==4 or p==4:
                                                                    if i not in [j,k,l] and j not in [i,k,l] and k not in [i,j,l] and l not in [i,j,k]:
                                                                        if m not in [q,o,p] and q not in [m,o,p] and o not in [m,q,p] and p not in [m,q,o]:
                                                                            if fast_traffic(i,j,k,l,m,q,o,p)==n:
                                                                                print_23(i,j,k,l,m,q,o,p)

# %%
def print_23(i,j,k,l,m,n,o,p):
    print('       '+str(i)+'       '+'             '+str(m)+'       ')
    print('  ┌────┐  '+'      ┌────┐  ')
    print('  │        │  '+'      │        │  ')
    print(str(j)+' │        │ '+str(k)+'    '+str(n)+' │        │ '+str(o))
    print('  │        │  '+'      │        │  ')
    print('  └────┘  '+'      └────┘  ')
    print('       '+str(l)+'       '+'             '+str(p)+'       ')
    print("")

# %%
def count_picture(n):
    cnt=0
    for i in range(1,5):
        for j in range(1,5):
            for k in range(1,5):
                for l in range(1,5):
                    for m in range(1,5):
                        for q in range(1,5):
                            for o in range(1,5):
                                for p in range(1,5):
                                    if i==1 or j==1 or k==1 or l==1:
                                        if m==1 or q==1 or o==1 or p==1:
                                            if i==2 or j==2 or k==2 or l==2:
                                                if m==2 or q==2 or o==2 or p==2:
                                                    if i==3 or j==3 or k==3 or l==3:
                                                        if m==3 or q==3 or o==3 or p==3:
                                                            if i==4 or j==4 or k==4 or l==4:
                                                                if m==4 or q==4 or o==4 or p==4:
                                                                    if i not in [j,k,l] and j not in [i,k,l] and k not in [i,j,l] and l not in [i,j,k]:
                                                                        if m not in [q,o,p] and q not in [m,o,p] and o not in [m,q,p] and p not in [m,q,o]:
                                                                            if fast_traffic(i,j,k,l,m,q,o,p)==n:
                                                                                cnt+=1
    return cnt

# %%
count_picture(6)
# Out:
# 133

# %%
def tritraffic_picture(n):
    for i in range(1,4):
        for j in range(1,4):
            for k in range(1,4):
                for l in range(1,4):
                    for m in range(1,4):
                        for q in range(1,4):
                            for o in range(1,4):
                                for p in range(1,4):
                                    if i==1 or j==1 or k==1 or l==1:
                                        if m==1 or q==1 or o==1 or p==1:
                                            if i==2 or j==2 or k==2 or l==2:
                                                if m==2 or q==2 or o==2 or p==2:
                                                    if i==3 or j==3 or k==3 or l==3:
                                                        if m==3 or q==3 or o==3 or p==3:
                                                            if i not in [j,k] and j not in [i,l] and k not in [i,l] and l not in [j,k]:
                                                                if m not in [q,o] and q not in [m,p] and o not in [m,p] and p not in [q,o]:
                                                                    if trifast_traffic(i,j,k,l,m,q,o,p)==n:
                                                                        print_23(i,j,k,l,m,q,o,p)

# %%
def tricount_picture(n):
    cnt=0
    for i in range(1,4):
        for j in range(1,4):
            for k in range(1,4):
                for l in range(1,4):
                    for m in range(1,4):
                        for q in range(1,4):
                            for o in range(1,4):
                                for p in range(1,4):
                                    if i==1 or j==1 or k==1 or l==1:
                                        if m==1 or q==1 or o==1 or p==1:
                                            if i==2 or j==2 or k==2 or l==2:
                                                if m==2 or q==2 or o==2 or p==2:
                                                    if i==3 or j==3 or k==3 or l==3:
                                                        if m==3 or q==3 or o==3 or p==3:
                                                            if i not in [j,k] and j not in [i,l] and k not in [i,l] and l not in [j,k]:
                                                                if m not in [q,o] and q not in [m,p] and o not in [m,p] and p not in [q,o]:
                                                                    if trifast_traffic(i,j,k,l,m,q,o,p)==n:
                                                                        cnt+=1
    return cnt

# %%
for i in tripath_traffic(1,3,3,2,2,1,3,2):
    print(i)
# Out:
# g-h-d
# e-f-d
# e-c-d

# %%
tritraffic1(1,3,3,2,2,1,3,2)
# Out:
# 8

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-468-1200cbde0c74> in <module>()
# ----> 1 aaaa()
#
# NameError: name 'aaaa' is not defined
