# %%
def traffic1 (a,b,c,d,e,f,g,h):
    
    goal=3
    cnt=0
    while True:
        if ((cnt+1)%4)==e%4 and goal==3:
            goal=2
            cnt+=3
        elif ((cnt+1)%4)==a%4 and goal==2:
            goal=1
            cnt+=1
        elif ((cnt+1)%4)==b%4 and goal==1:
            goal=4
            cnt+=1
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def traffic2 (a,b,c,d,e,f,g,h):
    goal=3
    cnt=0
    while True:
        if ((cnt+1)%4)==g%4 and goal==3:
            goal=6
            cnt+=1
        elif ((cnt+1)%4)==h%4 and goal==6:
            goal=5
            cnt+=3
        elif ((cnt+1)%4)==d%4 and goal==5:
            goal=4
            cnt+=1
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def traffic3 (a,b,c,d,e,f,g,h):
    goal=3
    cnt=0
    while True:
        if ((cnt+1)%4)==e%4 and goal==3:
            goal=2
            cnt+=1
            
        elif ((cnt+1)%4)==f%4 and goal==2:
            goal=5
            cnt+=3
            
        elif ((cnt+1)%4)==d%4 and goal==5:
            goal=4
            cnt+=1
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def traffic4 (a,b,c,d,e,f,g,h):
    goal=3
    cnt=0
    while True:
        if ((cnt+1)%4)==e%4 and goal==3:
            goal=2
            cnt+=3
        elif ((cnt+1)%4)==c%4 and goal==2:
            goal=5
            cnt+=1
        elif ((cnt+1)%4)==d%4 and goal==5:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def traffic5 (a,b,c,d,e,f,g,h):
    goal=3
    cnt=0
    while True:
        
        if ((cnt+1)%4)==g%4 and goal==3:
            goal=6
            cnt+=1       
        elif ((cnt+1)%4)==h%4 and goal==6:
            goal=5
            cnt+=1
        elif ((cnt+1)%4)==f%4 and goal==5:
            goal=2
            cnt+=3
        elif ((cnt+1)%4)==a%4 and goal==2:
            goal=1
            cnt+=1
        elif ((cnt+1)%4)==b%4 and goal==1:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def traffic6 (a,b,c,d,e,f,g,h):
    goal=3
    cnt=0
    while True:
        
        if ((cnt+1)%4)==g%4 and goal==3:
            goal=6
            cnt+=1    
        elif ((cnt+1)%4)==h%4 and goal==6:
            goal=5
            cnt+=3
        elif ((cnt+1)%4)==c%4 and goal==5:
            goal=2
            cnt+=1
        elif ((cnt+1)%4)==a%4 and goal==2:
            goal=1
            cnt+=1
        elif ((cnt+1)%4)==b%4 and goal==1:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def traffic7 (a,b,c,d,e,f,g,h):
    goal=3
    cnt=0
    while True:
        
        if ((cnt+1)%4)==e%4 and goal==3:
            goal=2
            cnt+=1    
        elif ((cnt+1)%4)==f%4 and goal==2:
            goal=5
            cnt+=3
        elif ((cnt+1)%4)==c%4 and goal==5:
            goal=20
            cnt+=1
        elif ((cnt+1)%4)==a%4 and goal==20:
            goal=1
            cnt+=1
        elif ((cnt+1)%4)==b%4 and goal==1:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

def traffic8 (a,b,c,d,e,f,g,h):
    goal=3
    cnt=0
    while True:
        
        if ((cnt+1)%4)==g%4 and goal==3:
            goal=6
            cnt+=1    
        elif ((cnt+1)%4)==h%4 and goal==6:
            goal=5
            cnt+=1
        elif ((cnt+1)%4)==f%4 and goal==5:
            goal=2
            cnt+=3
        elif ((cnt+1)%4)==c%4 and goal==2:
            goal=1
            cnt+=1
        elif ((cnt+1)%4)==d%4 and goal==1:
            goal=4
            cnt+=1
            
        else:
            cnt+=1
        
        if not goal==4:
            continue
            
        break
    
    return cnt

# %%
def fast_traffic(a,b,c,d,e,f,g,h):
    traf=[traffic1(a,b,c,d,e,f,g,h),traffic2(a,b,c,d,e,f,g,h),traffic3(a,b,c,d,e,f,g,h),traffic4(a,b,c,d,e,f,g,h),traffic5(a,b,c,d,e,f,g,h),traffic6(a,b,c,d,e,f,g,h),traffic7(a,b,c,d,e,f,g,h),traffic8(a,b,c,d,e,f,g,h)]
    return min(traf)
def path_traffic(a,b,c,d,e,f,g,h):
    num=['e-a-b','g-h-d','e-f-d','e-c-d','g-h-f-a-b','g-h-c-a-b','e-f-c-a-b','g-h-f-c-d']
    traf=[traffic1(a,b,c,d,e,f,g,h),traffic2(a,b,c,d,e,f,g,h),traffic3(a,b,c,d,e,f,g,h),traffic4(a,b,c,d,e,f,g,h),traffic5(a,b,c,d,e,f,g,h),traffic6(a,b,c,d,e,f,g,h),traffic7(a,b,c,d,e,f,g,h),traffic8(a,b,c,d,e,f,g,h)]
    temp = fast_traffic(a,b,c,d,e,f,g,h)
    for i in range(8):
        if temp==traf[i]:
            yield num[i]
def traffic_time(a,b,c,d,e,f,g,h):
    print(traffic1(a,b,c,d,e,f,g,h))
    print(traffic2(a,b,c,d,e,f,g,h))
    print(traffic3(a,b,c,d,e,f,g,h))
    print(traffic4(a,b,c,d,e,f,g,h))
    print(traffic5(a,b,c,d,e,f,g,h))
    print(traffic6(a,b,c,d,e,f,g,h))
    print(traffic7(a,b,c,d,e,f,g,h))
    print(traffic8(a,b,c,d,e,f,g,h))

# %%
def ft(p,q):
    if len(p)==4:
        if len(q)==4:
            return fast_traffic(p[0],p[1],p[2],p[3],q[0],q[1],q[2],q[3])
def pt(p,q):
    if len(p)==4:
        if len(q)==4:
            return path_traffic(p[0],p[1],p[2],p[3],q[0],q[1],q[2],q[3])

# %%
def print_23(i,j,k,l,m,n,o,p):
    print('       '+str(i)+'       '+'             '+str(m)+'       ')
    print('  ┌────┐  '+'      ┌────┐  ')
    print('  │        │  '+'      │        │  ')
    print(str(j)+' │        │ '+str(k)+'    '+str(n)+' │        │ '+str(o))
    print('  │        │  '+'      │        │  ')
    print('  └────┘  '+'      └────┘  ')
    print('       '+str(l)+'       '+'             '+str(p)+'       ')
    print("")

# %%
def count_picture(n):
    cnt=0
    for i in range(1,5):
        for j in range(1,5):
            for k in range(1,5):
                for l in range(1,5):
                    for m in range(1,5):
                        for q in range(1,5):
                            for o in range(1,5):
                                for p in range(1,5):
                                    if i==1 or j==1 or k==1 or l==1:
                                        if m==1 or q==1 or o==1 or p==1:
                                            if i==2 or j==2 or k==2 or l==2:
                                                if m==2 or q==2 or o==2 or p==2:
                                                    if i==3 or j==3 or k==3 or l==3:
                                                        if m==3 or q==3 or o==3 or p==3:
                                                            if i==4 or j==4 or k==4 or l==4:
                                                                if m==4 or q==4 or o==4 or p==4:
                                                                    if i not in [j,k,l] and j not in [i,k,l] and k not in [i,j,l] and l not in [i,j,k]:
                                                                        if m not in [q,o,p] and q not in [m,o,p] and o not in [m,q,p] and p not in [m,q,o]:
                                                                            if fast_traffic(i,j,k,l,m,q,o,p)==n:
                                                                                cnt+=1
    return cnt

# %%
fast_traffic(1,2,2,3,3,2,1,3)
# Out:
# 7

# %%
for i in path_traffic(1,2,2,3,3,2,1,3):
    print(i)
# Out:
# g-h-d
# e-c-d
